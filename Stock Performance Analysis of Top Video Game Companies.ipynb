# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# read csv file data
data = pd.read_csv(r"C:\Users\Manikanta\Downloads\VideoGameStocks.csv")
data
# Out:
#             Date                         Company Ticker Symbol Currency  \
# 0     2000-01-01  Sony Interactive Entertainment          SONY      JPY
# 1     2000-02-01  Sony Interactive Entertainment          SONY      JPY
# 2     2000-03-01  Sony Interactive Entertainment          SONY      JPY
# 3     2000-04-01  Sony Interactive Entertainment          SONY      JPY
# 4     2000-05-01  Sony Interactive Entertainment          SONY      JPY
# ...          ...                             ...           ...      ...
# 2204  2024-06-01                        Playtika          PLTK      USD
# 2205  2024-07-01                        Playtika          PLTK      USD
# 2206  2024-08-01                        Playtika          PLTK      USD
# 2207  2024-09-01                        Playtika          PLTK      USD
# 2208  2024-10-01                        Playtika          PLTK      USD
#
#            Open       High        Low      Close  Adj Close     Volume
# ...

# %%
# Convert the 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')

# Check for missing or invalid data
data.dropna(inplace=True)  # Drop rows with missing values
data = data.drop_duplicates()  # Remove duplicate rows

# %%
# extract year and month from date column
data['Year']=data['Date'].dt.year
data['Month']=data['Date'].dt.month_name()
data
# Out:
#            Date                         Company Ticker Symbol Currency  \
# 0    2000-01-01  Sony Interactive Entertainment          SONY      JPY
# 1    2000-02-01  Sony Interactive Entertainment          SONY      JPY
# 2    2000-03-01  Sony Interactive Entertainment          SONY      JPY
# 3    2000-04-01  Sony Interactive Entertainment          SONY      JPY
# 4    2000-05-01  Sony Interactive Entertainment          SONY      JPY
# ...         ...                             ...           ...      ...
# 2204 2024-06-01                        Playtika          PLTK      USD
# 2205 2024-07-01                        Playtika          PLTK      USD
# 2206 2024-08-01                        Playtika          PLTK      USD
# 2207 2024-09-01                        Playtika          PLTK      USD
# 2208 2024-10-01                        Playtika          PLTK      USD
#
#            Open       High        Low      Close  Adj Close     Volume  Year  \
# ...

# %%
# Add a column for Monthly Returns if the 'Close' column exists
data['Monthly Return (%)'] = data['Close'].pct_change() * 100
data
# Out:
#            Date                         Company Ticker Symbol Currency  \
# 0    2000-01-01  Sony Interactive Entertainment          SONY      JPY
# 1    2000-02-01  Sony Interactive Entertainment          SONY      JPY
# 2    2000-03-01  Sony Interactive Entertainment          SONY      JPY
# 3    2000-04-01  Sony Interactive Entertainment          SONY      JPY
# 4    2000-05-01  Sony Interactive Entertainment          SONY      JPY
# ...         ...                             ...           ...      ...
# 2204 2024-06-01                        Playtika          PLTK      USD
# 2205 2024-07-01                        Playtika          PLTK      USD
# 2206 2024-08-01                        Playtika          PLTK      USD
# 2207 2024-09-01                        Playtika          PLTK      USD
# 2208 2024-10-01                        Playtika          PLTK      USD
#
#            Open       High        Low      Close  Adj Close     Volume  Year  \
# ...

# %%
# average closing price for each company and round it into two decimal points
avg_close_price_by_company = round(data.groupby('Company')['Close'].mean(),2)
avg_close_price_by_company
# Out:
# Company
# Electronic Arts                       63.79
# Embracer Group                        47.04
# Microsoft Gaming                      90.83
# NetEase Games                         31.03
# Nintendo                               6.70
# Playtika                              14.09
# Roblox Corporation                    49.79
# Sony Interactive Entertainment         9.79
# Take-Two Interactive                  53.80
# Tencent Interactive Entertainment    169.57
# Name: Close, dtype: float64

# %%
# top 5 companies by trading volume
top_5_volume = data.groupby('Company')['Volume'].sum().sort_values(ascending=False).head(5)
top_5_volume
# Out:
# Company
# Microsoft Gaming                     313533139100
# Tencent Interactive Entertainment    123213765003
# NetEase Games                         49370020100
# Sony Interactive Entertainment        36589344100
# Electronic Arts                       28668435200
# Name: Volume, dtype: int64

# %%
# calculate overall mean and median closing price
mean_close = round(np.mean(data['Close']),2)
median_close = round(np.median(data['Close']),2)
print(f'mean_close = {mean_close}\nmedian_close = {median_close}')
# Out:
# mean_close = 56.45
# median_close = 22.38

# %%
#Line Plot of Average Closing Prices by Year
avg_close_by_year = data.groupby('Year')['Close'].mean()
plt.figure(figsize=(8, 6))
avg_close_by_year.plot(kind='line', marker='o', color='blue')
plt.title('Average Closing Prices by Year')
plt.xlabel('Year')
plt.ylabel('Average Closing Price')
plt.show()

# %%
# Bar Chart of Top 5 Companies by Trading Volume
plt.figure(figsize=(8, 6))
top_5_volume.plot(kind='bar', color='orange', edgecolor='black')
plt.title('Top 5 Companies by Total Trading Volume')
plt.xlabel('Company')
plt.ylabel('Total Volume')
plt.show()
